# %% [markdown]
# # 0. Índice <a name="Contents"></a>
# 1. [Importando bibliotecas](#import)
# 2. [Árvore do exemplo de Overfitting](#exemplo)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # 2. Árvore do exemplo de Overfitting <a name="exemplo"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
x1 = np.array([10,22,13,42,25,36,24])
x2 = np.array([100,200,300,400,500,600,400])
y = np.array([0,0,0,1,0,1,1])

# %%
teste = pd.DataFrame({'x1': x1, 'x2':x2})

# %%
teste.head()
# Out:
#    x1   x2
# 0  10  100
# 1  22  200
# 2  13  300
# 3  42  400
# 4  25  500

# %%
clf = DecisionTreeClassifier(random_state=100)
clf
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
clf = clf.fit(teste,y)
clf
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
plt.figure(figsize=(25, 10))
plot_tree(clf,
          filled=True,
          class_names=['não', 'sim'],
          feature_names=['x1','x2']);
