# %%
import folium
from folium import plugins

# %%
coordenadas = [[44.6916, -63.2588],
[44.6918, -63.2575],
[44.6911, -63.2572],
[44.6910, -63.2570],
[44.6906, -63.2573],
[44.6901, -63.2574],
[44.6897, -63.2575],
[44.6892, -63.2574],
[44.6887,-63.2574],
[44.6884, -63.2574],
[44.6882, -63.2575],
[44.6880, -63.2577],
[44.6877, -63.2579],
[44.6876, -63.2582],
[44.6873, -63.2585],
[44.6877, -63.2608],
[44.6880, -63.2629],
[44.6881, -63.2643],
[44.6883, -63.2659],
[44.6883, -63.2666],
[44.6882, -63.2678],
[44.6880, -63.2689],
[44.6873, -63.2687],
[44.6867, -63.2683],
[44.6862, -63.2679],
[44.6854, -63.2673],
[44.6849, -63.2668],
[44.6843, -63.2663],
[44.6837, -63.2657],
[44.6831, -63.2652],
[44.6824, -63.2644],
[44.6818, -63.2639],
[44.6813, -63.2635],
[44.6807, -63.2631],
[44.6803, -63.2628],
[44.6797, -63.2626],
[44.6792, -63.2624],
[44.6787, -63.2623],
[44.6783, -63.2623],
[44.6778, -63.2623],
[44.6773, -63.2624],
[44.6769, -63.2624],
[44.6764, -63.2624],
[44.6760, -63.2625],
[44.6753, -63.2625],
[44.6747, -63.2626],
[44.6741, -63.2626]
]

# %%
mapa_linhas = folium.Map(location = [44.6134, -63.3698], zoom_start = 11, control_scale = True, 
                         tiles = "cartodbpositron")

folium.Marker(location = [44.6916, -63.2588], 
              popup = "St. Therese Community Centre, 17 Conrod Rd.", 
              icon = folium.Icon(icon = "glyphicon glyphicon-home",
                                 color = "darkred",
                                 icon_color = "white",
                                 prefix = "glyphicon")).add_to(mapa_linhas)

folium.Marker(location = [44.6495, -63.3028], 
              popup = "1st Water Station", 
              icon = folium.Icon(icon = "glyphicon glyphicon-glass",
                                 color = "darkblue",
                                 icon_color = "white",
                                 prefix = "glyphicon")).add_to(mapa_linhas)


for i in range(len(coordenadas)-1):
    folium.PolyLine(locations = [[coordenadas[i][0], coordenadas[i][1]], [coordenadas[i+1][0], coordenadas[i+1][1]]],
                   color = 'navy').add_to(mapa_linhas)
    
mapa_linhas.add_child(folium.LatLngPopup())

mapa_linhas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d0592eb579cc22e58eaeee72e9404dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d0592eb579cc22e58eaeee72e9404dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d0592eb579cc22e58eaeee72e9404dd = L.map(
#                 &quot;map_8d0592eb579cc22e58eaeee72e9404dd&quot;,
#                 {
#                     center: [44.6134, -63.3698],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8d0592eb579cc22e58eaeee72e9404dd);
#
#
#
#
#
#             var tile_layer_c2b294245265fd046e9739d68d61b438 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2b294245265fd046e9739d68d61b438.addTo(map_8d0592eb579cc22e58eaeee72e9404dd);
#
#
#             var marker_2fd7f0c4ddf335724f33e9ab4a8af8fd = L.marker(
#                 [44.6916, -63.2588],
#                 {}
#             ).addTo(map_8d0592eb579cc22e58eaeee72e9404dd);
#
#
#             var icon_6464f0b4170c5372f6d2c8e8118c356b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2fd7f0c4ddf335724f33e9ab4a8af8fd.setIcon(icon_6464f0b4170c5372f6d2c8e8118c356b);
#
#
#         var popup_60ec228298684d761d6478f6b235d09d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_983146b85039c3909d365477b11741ed = $(`&lt;div id=&quot;html_983146b85039c3909d365477b11741ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St. Therese Community Centre, 17 Conrod Rd.&lt;/div&gt;`)[0];
#                 popup_60ec228298684d761d6478f6b235d09d.setContent(html_983146b85039c3909d365477b11741ed);
#
#
#
#         marker_2fd7f0c4ddf335724f33e9ab4a8af8fd.bindPopup(popup_60ec228298684d761d6478f6b235d09d)
#         ;
#
#
#
#
#             var marker_10b4503ba8100441281799b2e458516f = L.marker(
#                 [44.6495, -63.3028],
#                 {}
#             ).addTo(map_8d0592eb579cc22e58eaeee72e9404dd);
#
#
#             var icon_2c0149ee15bbdf4756cdfedb2b6cd7bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-glass&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_10b4503ba8100441281799b2e458516f.setIcon(icon_2c0149ee15bbdf4756cdfedb2b6cd7bd);
#
#
#         var popup_60ddeba7b77a52e3350498a8777d6868 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_874ec71988be304af56d795b3a385ff4 = $(`&lt;div id=&quot;html_874ec71988be304af56d795b3a385ff4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1st Water Station&lt;/div&gt;`)[0];
#                 popup_60ddeba7b77a52e3350498a8777d6868.setContent(html_874ec71988be304af56d795b3a385ff4);
#
#
#
#         marker_10b4503ba8100441281799b2e458516f.bindPopup(popup_60ddeba7b77a52e3350498a8777d6868)
#         ;
#
#
#
#
#             var poly_line_51dc32cccff69e8385ae3d6570764a30 = L.polyline(
#                 [[44.6916, -63.2588], [44.6918, -63.2575]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;navy&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;navy&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d0592eb579cc22e58eaeee72e9404dd);
#
#
#             var poly_line_bcaa509997c95932d0dcec1fb364cd40 = L.polyline(
#                 [[44.6918, -63.2575], [44.6911, -63.2572]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;navy&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;navy&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d0592eb579cc22e58eaeee72e9404dd);
