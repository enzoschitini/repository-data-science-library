# %%
import pandas as pd

# %%
df = pd.read_csv('Propostas.csv')
df = df.drop('Unnamed: 0', axis=1)
df = df.dropna(subset=['Defalt'])
total, _ = df.shape
df.head()
# Out:
#          ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2   5008806           M            Y               Y             0
# 5   5008810           F            N               Y             0
# 6   5008811           F            N               Y             0
# 11  5112956           M            Y               Y             0
# 19  5008825           F            Y               N             0
#
#     AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 2           112500.0               Working  Secondary / secondary special
# 5           270000.0  Commercial associate  Secondary / secondary special
# 6           270000.0  Commercial associate  Secondary / secondary special
# 11          270000.0               Working               Higher education
# 19          130500.0               Working              Incomplete higher
#
#       NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
df_pago = df[df['Defalt'] == 0]
total_pago, _ = df_pago.shape

# %%
(total_pago / total) * 100
# Out:
# 99.9039039039039

# %%
df_sem_pagar = df[df['Defalt'] == 1]
total_sem_pagar, _ = df_sem_pagar.shape
