# %% [markdown]
# # Índice <a name="Contents"></a>
# 1. [Importando bibliotecas](#import)
# 2. [Construindo um dataframe](#read)
# 3. [Renomeando colunas](#colunas)
# 4. [Renomeando índices](#indices)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# # 2. Construindo um dataframe <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df = pd.DataFrame(
    np.random.randn(9, 4)*100,
    index=["A", "B", "C", "D", "E", "F", "G", "H", "I"],
    columns=["coluna1", "coluna2", "coluna3","coluna4"],
)
df
# Out:
#       coluna1     coluna2     coluna3     coluna4
# A   12.293769  -42.058811 -170.808551  142.018413
# B   57.775532   33.574917   54.097090   58.687994
# C   25.911798   62.334575  186.275664  128.335777
# D  -26.905264   -5.068961 -160.697496  -24.506892
# E -163.998945  -76.944723   37.853548   64.686024
# F   83.675813  -79.867158  -25.193907   39.480153
# G   11.528924   43.754940  -18.586039   10.881250
# H  135.048332 -135.345844   -4.002469  -19.711198
# I   20.673699  140.879422   32.933833  169.291121

# %% [markdown]
# # 3. Renomeando colunas <a name="colunas"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df.columns
# Out:
# Index(['coluna1', 'coluna2', 'coluna3', 'coluna4'], dtype='object')

# %%
df.columns = ['segunda', 'terça', 'quarta', 'quinta']

# %%
df.columns
# Out:
# Index(['segunda', 'terça', 'quarta', 'quinta'], dtype='object')

# %%
df
# Out:
#       segunda       terça      quarta      quinta
# A   12.293769  -42.058811 -170.808551  142.018413
# B   57.775532   33.574917   54.097090   58.687994
# C   25.911798   62.334575  186.275664  128.335777
# D  -26.905264   -5.068961 -160.697496  -24.506892
# E -163.998945  -76.944723   37.853548   64.686024
# F   83.675813  -79.867158  -25.193907   39.480153
# G   11.528924   43.754940  -18.586039   10.881250
# H  135.048332 -135.345844   -4.002469  -19.711198
# I   20.673699  140.879422   32.933833  169.291121

# %% [markdown]
# # 4. Renomeando índices <a name="indices"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df['coluna5'] = ['letraA','letraB','letraC','letraD','letraE','letraF','letraG','letraH','letraI']

# %%
df
# Out:
#       segunda       terça      quarta      quinta coluna5
# A   12.293769  -42.058811 -170.808551  142.018413  letraA
# B   57.775532   33.574917   54.097090   58.687994  letraB
# C   25.911798   62.334575  186.275664  128.335777  letraC
# D  -26.905264   -5.068961 -160.697496  -24.506892  letraD
# E -163.998945  -76.944723   37.853548   64.686024  letraE
# F   83.675813  -79.867158  -25.193907   39.480153  letraF
# G   11.528924   43.754940  -18.586039   10.881250  letraG
# H  135.048332 -135.345844   -4.002469  -19.711198  letraH
# I   20.673699  140.879422   32.933833  169.291121  letraI

# %%
df.set_index('coluna5')
# Out:
#             segunda       terça      quarta      quinta
# coluna5
# letraA    12.293769  -42.058811 -170.808551  142.018413
# letraB    57.775532   33.574917   54.097090   58.687994
# letraC    25.911798   62.334575  186.275664  128.335777
# letraD   -26.905264   -5.068961 -160.697496  -24.506892
# letraE  -163.998945  -76.944723   37.853548   64.686024
# letraF    83.675813  -79.867158  -25.193907   39.480153
# letraG    11.528924   43.754940  -18.586039   10.881250
# letraH   135.048332 -135.345844   -4.002469  -19.711198
# letraI    20.673699  140.879422   32.933833  169.291121

# %%
df
# Out:
#       segunda       terça      quarta      quinta coluna5
# A   12.293769  -42.058811 -170.808551  142.018413  letraA
# B   57.775532   33.574917   54.097090   58.687994  letraB
# C   25.911798   62.334575  186.275664  128.335777  letraC
# D  -26.905264   -5.068961 -160.697496  -24.506892  letraD
# E -163.998945  -76.944723   37.853548   64.686024  letraE
# F   83.675813  -79.867158  -25.193907   39.480153  letraF
# G   11.528924   43.754940  -18.586039   10.881250  letraG
# H  135.048332 -135.345844   -4.002469  -19.711198  letraH
# I   20.673699  140.879422   32.933833  169.291121  letraI

# %%
df.reset_index()
# Out:
#   index     segunda       terça      quarta      quinta coluna5
# 0     A   12.293769  -42.058811 -170.808551  142.018413  letraA
# 1     B   57.775532   33.574917   54.097090   58.687994  letraB
# 2     C   25.911798   62.334575  186.275664  128.335777  letraC
# 3     D  -26.905264   -5.068961 -160.697496  -24.506892  letraD
# 4     E -163.998945  -76.944723   37.853548   64.686024  letraE
# 5     F   83.675813  -79.867158  -25.193907   39.480153  letraF
# 6     G   11.528924   43.754940  -18.586039   10.881250  letraG
# 7     H  135.048332 -135.345844   -4.002469  -19.711198  letraH
# 8     I   20.673699  140.879422   32.933833  169.291121  letraI

# %%
df.reset_index(drop=True)
# Out:
#       segunda       terça      quarta      quinta coluna5
# 0   12.293769  -42.058811 -170.808551  142.018413  letraA
# 1   57.775532   33.574917   54.097090   58.687994  letraB
# 2   25.911798   62.334575  186.275664  128.335777  letraC
# 3  -26.905264   -5.068961 -160.697496  -24.506892  letraD
# 4 -163.998945  -76.944723   37.853548   64.686024  letraE
# 5   83.675813  -79.867158  -25.193907   39.480153  letraF
# 6   11.528924   43.754940  -18.586039   10.881250  letraG
# 7  135.048332 -135.345844   -4.002469  -19.711198  letraH
# 8   20.673699  140.879422   32.933833  169.291121  letraI
